# %%
import cv2 
import numpy as np

# ---① 연산에 사용할 배열 생성
a = np.uint8([[200, 50]]) 
b = np.uint8([[100, 100]])

#---② NumPy 배열 직접 연산
add1 = a + b
sub1 = a - b
mult1 = a * 2
div1 = a / 3

# ---③ OpenCV API를 이용한 연산
add2 = cv2.add(a, b)
sub2 = cv2.subtract(a, b)
mult2 = cv2.multiply(a , 2)
div2 = cv2.divide(a, 3)

#---④ 각 연산 결과 출력
print(add1, add2)
print(sub1, sub2)
print(mult1, mult2)
print(div1, div2)

# %%
a + b

# %%
300-256

# %%
a-b

# %%
256-50

# %%
a * 2

# %%
print(200 * 2-256)

# %%
print(50*2)

# %%
200/2

# %%
a/3

# %%
div2

# %%
# 알파블렌딩

# %%
import cv2
import numpy as np

alpha = 0.5 # 합성에 사용할 알파 값

#---① 합성에 사용할 영상 읽기
img1 = cv2.imread('../../data/img/aaa.jpg')
img2 = cv2.imread('../../data/img/bbb.png')

# ---② NumPy 배열에 수식을 직접 연산해서 알파 블렌딩 적용
blended = img1 * alpha + img2 * (1-alpha)
blended = blended.astype(np.uint8) # 소수점 발생을 제거하기 위함
cv2.imshow('img1 * alpha + img2 * (1-alpha)', blended)

# ---③ addWeighted() 함수로 알파 블렌딩 적용
dst = cv2.addWeighted(img1, alpha, img2, (1-alpha), 0) 
cv2.imshow('cv2.addWeighted', dst)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 11
#       8 img2 = cv2.imread('../data/img/bbb.png')
#      10 # ---② NumPy 배열에 수식을 직접 연산해서 알파 블렌딩 적용
# ---> 11 blended = img1 * alpha + img2 * (1-alpha)
#      12 blended = blended.astype(np.uint8) # 소수점 발생을 제거하기 위함
#      13 cv2.imshow('img1 * alpha + img2 * (1-alpha)', blended)
#
# ValueError: operands could not be broadcast together with shapes (512,680,3) (719,606,3)

# %%
import cv2
import numpy as np

alpha = 0.5 # 합성에 사용할 알파 값

#---① 합성에 사용할 영상 읽기
img1 = cv2.imread('../data/img/bbb.png')
img2 = cv2.imread('../data/img/aaa.jpg')

# 이미지가 제대로 읽혔는지 확인
if img1 is None or img2 is None:
    print("Error: One or both image files could not be loaded.")
    exit()

# 이미지 크기 조정 (선택 사항: 두 이미지의 크기를 맞추기)
if img1.shape != img2.shape:
    # 두 이미지 중 작은 이미지에 맞추어 다른 이미지를 리사이즈
    new_size = (min(img1.shape[1], img2.shape[1]), min(img1.shape[0], img2.shape[0]))
    img1 = cv2.resize(img1, new_size)
    img2 = cv2.resize(img2, new_size)

# ---② NumPy 배열에 수식을 직접 연산해서 알파 블렌딩 적용
blended = img1 * alpha + img2 * (1-alpha)
blended = blended.astype(np.uint8) # 소수점 발생을 제거하기 위함
cv2.imshow('img1 * alpha + img2 * (1-alpha)', blended)

# ---③ addWeighted() 함수로 알파 블렌딩 적용
dst = cv2.addWeighted(img1, alpha, img2, (1-alpha), 0) 
cv2.imshow('cv2.addWeighted', dst)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

alpha = 0.5 # 합성에 사용할 알파 값

#---① 합성에 사용할 영상 읽기
img1 = cv2.imread('../data/img/bbb.png')
img2 = cv2.imread('../data/img/aaa.jpg')

# 이미지가 제대로 읽혔는지 확인
if img1 is None or img2 is None:
    print("Error: One or both image files could not be loaded.")
    exit()

# 이미지 크기 조정 (선택 사항: 두 이미지의 크기를 맞추기)
if img1.shape != img2.shape:
    # 두 이미지 중 작은 이미지에 맞추어 다른 이미지를 리사이즈
    new_size = (min(img1.shape[1], img2.shape[1]), min(img1.shape[0], img2.shape[0]))
    img1 = cv2.resize(img1, new_size)
    img2 = cv2.resize(img2, new_size)
 
# ---② 이미지 덧셈
img3 = img1 + img2  # 더하기 연산
img4 = cv2.add(img1, img2) # OpenCV 함수
imgs = {'img1':img1, 'img2':img2, 'img1+img2': img3, 'cv.add(img1, img2)': img4}
 
# ---③ 이미지 출력
for i, (k, v) in enumerate(imgs.items()):
    plt.subplot(2,2, i + 1)
    plt.imshow(v[:,:,::-1])
    plt.title(k)
    plt.xticks([]); plt.yticks([])

plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

# 합성에 사용할 알파 값
alpha = 0.5 
#---① 합성에 사용할 영상 읽기
img1 = cv2.imread('../../data/img/bbb.png')
img2 = cv2.imread('../../data/img/aaa.jpg')

# 이미지가 제대로 읽혔는지 확인
if img1 is None or img2 is None:
    print("Error: One or both image files could not be loaded.")
    exit()

# 이미지 크기 조정 (선택 사항: 두 이미지의 크기를 맞추기)
if img1.shape != img2.shape:
    # 두 이미지 중 작은 이미지에 맞추어 다른 이미지를 리사이즈
    new_size = (min(img1.shape[1], img2.shape[1]), min(img1.shape[0], img2.shape[0]))
    img1 = cv2.resize(img1, new_size)
    img2 = cv2.resize(img2, new_size)

# ---② 이미지 덧셈
img3 = img1 + img2  # 더하기 연산
img4 = cv2.add(img1, img2) # OpenCV 함수
imgs = {'img1':img1, 'img2':img2, 'img1+img2': img3, 'cv.add(img1, img2)': img4}

# ---② NumPy 배열에 수식을 직접 연산해서 알파 블렌딩 적용
blended = img1 * alpha + img2 * (1-alpha)
# 반드시 필요하다
# 소수점 발생을 제거하기 위함
blended = blended.astype(np.uint8)
# cv2.imshow('img1 * alpha + img2 * (1-alpha)', blended)

# ---③ addWeighted() 함수로 알파 블렌딩 적용
dst = cv2.addWeighted(img1, alpha, img2, (1-alpha), 0) 
cv2.imshow('cv2.addWeighted', dst)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

# 합성에 사용할 알파 값
alpha = 0.5 
#---① 합성에 사용할 영상 읽기
img1 = cv2.imread('../../data/img/bbb.png')
img2 = cv2.imread('../../data/img/aaa.jpg')

# 이미지가 제대로 읽혔는지 확인
if img1 is None or img2 is None:
    print("Error: One or both image files could not be loaded.")
    exit()

# 이미지 크기 조정 (선택 사항: 두 이미지의 크기를 맞추기)
if img1.shape != img2.shape:
    # 두 이미지 중 작은 이미지에 맞추어 다른 이미지를 리사이즈
    new_size = (min(img1.shape[1], img2.shape[1]), min(img1.shape[0], img2.shape[0]))
    img1 = cv2.resize(img1, new_size)
    img2 = cv2.resize(img2, new_size)

# ---② 이미지 덧셈
img3 = img1 + img2  # 더하기 연산
img4 = cv2.add(img1, img2) # OpenCV 함수
imgs = {'img1':img1, 'img2':img2, 'img1+img2': img3, 'cv.add(img1, img2)': img4}

# ---② NumPy 배열에 수식을 직접 연산해서 알파 블렌딩 적용
blended = img1 * alpha + img2 * (1-alpha)
# 반드시 필요하다
# 소수점 발생을 제거하기 위함
blended = blended.astype(np.uint8)
cv2.imshow('img1 * alpha + img2 * (1-alpha)', blended)

# ---③ addWeighted() 함수로 알파 블렌딩 적용
# dst = cv2.addWeighted(img1, alpha, img2, (1-alpha), 0) 
# cv2.imshow('cv2.addWeighted', dst)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

win_name = 'Alpha blending'     # 창 이름
trackbar_name = 'fade'          # 트렉바 이름

# ---① 트렉바 이벤트 핸들러 함수
def onChange(x):
    alpha = x/100
    dst = cv2.addWeighted(img1, 1-alpha, img2, alpha, 0) 
    cv2.imshow(win_name, dst)


# ---② 합성 영상 읽기
img1 = cv2.imread('../../data/img/ddd.png')
img2 = cv2.imread('../../data/img/ccc.png')

# 이미지 크기 조정 (선택 사항: 두 이미지의 크기를 맞추기)
if img1.shape != img2.shape:
    # 두 이미지 중 작은 이미지에 맞추어 다른 이미지를 리사이즈
    new_size = (min(img1.shape[1], img2.shape[1]), min(img1.shape[0], img2.shape[0]))
    img1 = cv2.resize(img1, new_size)
    img2 = cv2.resize(img2, new_size)


# ---③ 이미지 표시 및 트렉바 붙이기
cv2.imshow(win_name, img1)
cv2.createTrackbar(trackbar_name, win_name, 0, 100, onChange)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
import numpy as np, cv2
import matplotlib.pylab as plt

#--① 연산에 사용할 이미지 생성
img1 = np.zeros( ( 200,400), dtype=np.uint8)
img2 = np.zeros( ( 200,400), dtype=np.uint8)
img1[:, :200] = 255         # 왼쪽은 흰색(255), 오른쪽은 검정색(0)
img2[100:200, :] = 255      # 위쪽은 검정색(0), 아래쪽은 흰색(255)

#--② 비트와이즈 연산
bitAnd = cv2.bitwise_and(img1, img2)
bitOr = cv2.bitwise_or(img1, img2)
bitXor = cv2.bitwise_xor(img1, img2)
bitNot = cv2.bitwise_not(img1)

#--③ Plot으로 결과 출력
imgs = {'img1':img1, 'img2':img2, 'and':bitAnd, 
          'or':bitOr, 'xor':bitXor, 'not(img1)':bitNot}
for i, (title, img) in enumerate(imgs.items()):
    plt.subplot(3,2,i+1)
    plt.title(title)
    plt.imshow(img, 'gray')
    plt.xticks([]); plt.yticks([])

plt.show()

# %%
import numpy as np, cv2
import matplotlib.pylab as plt
import ctypes  

# OpenCV 창 이름을 변경하는 함수 
def set_window_title(window_name, title):
  # 윈도우에서 사용할 수 있는 창 핸들을 가져옴
  hwnd = ctypes.windll.user32.FindWindowW(None, window_name)
  if hwnd != 0:
    # 창 이름을 변경
    ctypes.windll.user32.SetWindowTextW(hwnd, title)

#--① 이미지 읽기
img = cv2.imread('../../data/img/eee.png')

#--② 마스크 만들기
mask = np.zeros_like(img)
cv2.circle(mask, (150,140), 100, (255,255,255), -1)
#cv2.circle(대상이미지, (원점x, 원점y), 반지름, (색상), 채우기)

#--③ 마스킹
masked = cv2.bitwise_and(img, mask)

window_name = 'Test Window'
#--④ 결과 출력
cv2.imshow(window_name, img)
set_window_title(window_name, "오지리날_original")

cv2.imshow('mask', mask)
cv2.imshow('masked', masked)  

cv2.waitKey()
cv2.destroyAllWindows()

# %%
import numpy as np, cv2
import matplotlib.pylab as plt

#--① 이미지 읽기
img = cv2.imread('../data/img/cropped.jpg')

#--② 마스크 만들기
mask = np.zeros(img.shape[:2], dtype=np.uint8)
cv2.circle(mask, (150,140), 100, (255), -1)
#cv2.circle(대상이미지, (원점x, 원점y), 반지름, (색상), 채우기)

#--③ 마스킹
masked = cv2.bitwise_and(img, img, mask=mask)

#--④ 결과 출력
cv2.imshow('original', img)
cv2.imshow('mask', mask)
cv2.imshow('masked', masked)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

#--① 합성에 사용할 영상 읽기, 전경 영상은 4채널 png 파일
img_fg = cv2.imread('../data/img/cat_alpha.jpg', cv2.IMREAD_UNCHANGED)
img_bg = cv2.imread('../data/img/bbb.png')

#--② 알파채널을 이용해서 마스크와 역마스크 생성
_, mask = cv2.threshold(img_fg[:,:,3], 1, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

#--③ 전경 영상 크기로 배경 영상에서 ROI 잘라내기
img_fg = cv2.cvtColor(img_fg, cv2.COLOR_BGRA2BGR)
h, w = img_fg.shape[:2]
roi = img_bg[10:10+h, 10:10+w ]

#--④ 마스크 이용해서 오려내기
masked_fg = cv2.bitwise_and(img_fg, img_fg, mask=mask)
masked_bg = cv2.bitwise_and(roi, roi, mask=mask_inv)

#--⑥ 이미지 합성
added = masked_fg + masked_bg
img_bg[10:10+h, 10:10+w] = added

cv2.imshow('mask', mask)
cv2.imshow('mask_inv', mask_inv)
cv2.imshow('masked_fg', masked_fg)
cv2.imshow('masked_bg', masked_bg)
cv2.imshow('added', added)
cv2.imshow('result', img_bg)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 9
#       6 img_bg = cv2.imread('../data/img/bbb.png')
#       8 #--② 알파채널을 이용해서 마스크와 역마스크 생성
# ----> 9 _, mask = cv2.threshold(img_fg[:,:,3], 1, 255, cv2.THRESH_BINARY)
#      10 mask_inv = cv2.bitwise_not(mask)
#      12 #--③ 전경 영상 크기로 배경 영상에서 ROI 잘라내기
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import cv2
import numpy as np
import os

# 파일 경로 설정 (절대 경로 사용)
foreground_path = '../data/img/opencv_logo.png'
background_path = '../data/img/cropped.jpg'

# 이미지 파일이 존재하는지 확인
if not os.path.isfile(foreground_path):
    raise FileNotFoundError(f"Foreground image not found or unable to load: {foreground_path}")

if not os.path.isfile(background_path):
    raise FileNotFoundError(f"Background image not found or unable to load: {background_path}")

# --① 합성에 사용할 영상 읽기, 전경 영상은 4채널 png 파일
img_fg = cv2.imread(foreground_path, cv2.IMREAD_UNCHANGED)
img_bg = cv2.imread(background_path)

# 파일을 제대로 읽었는지 확인
if img_fg is None or img_bg is None:
    raise ValueError("Error loading images.")

# --② 알파채널을 이용해서 마스크와 역마스크 생성
if img_fg.shape[2] == 4:
    # Alpha channel present
    alpha_channel = img_fg[:, :, 3]
    _, mask = cv2.threshold(alpha_channel, 1, 255, cv2.THRESH_BINARY)
    mask = mask.astype(np.uint8)  # Ensure mask is uint8
    mask_inv = cv2.bitwise_not(mask)
    img_fg = cv2.cvtColor(img_fg, cv2.COLOR_BGRA2BGR)
else:
    # No alpha channel present
    mask = np.ones((img_fg.shape[0], img_fg.shape[1]), dtype=np.uint8) * 255
    mask_inv = np.zeros_like(mask)

# --③ 전경 영상 크기로 배경 영상에서 ROI 잘라내기
h, w = img_fg.shape[:2]

# Check if ROI dimensions are within the background image
if h > img_bg.shape[0] or w > img_bg.shape[1]:
    raise ValueError("Foreground image is larger than the background image.")

# Extract ROI from background
roi = img_bg[10:10 + h, 10:10 + w]

# Ensure ROI has the same number of channels as img_fg
if roi.shape[2] == 3:  # Convert ROI to have 4 channels if needed
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2BGRA)

# --④ 마스크 이용해서 오려내기
if roi.shape[:2] != mask.shape[:2]:
    roi = cv2.resize(roi, (mask.shape[1], mask.shape[0]), interpolation=cv2.INTER_AREA)

masked_fg = cv2.bitwise_and(img_fg, img_fg, mask=mask)
masked_bg = cv2.bitwise_and(roi, roi, mask=mask_inv)

# --⑥ 이미지 합성
if masked_fg.shape[:2] != masked_bg.shape[:2]:
    masked_bg = cv2.resize(masked_bg, (masked_fg.shape[1], masked_fg.shape[0]), interpolation=cv2.INTER_AREA)

# Ensure same number of channels
if masked_bg.shape[2] == 3 and masked_fg.shape[2] == 3:
    masked_bg = cv2.cvtColor(masked_bg, cv2.COLOR_BGRA2BGR)
elif masked_bg.shape[2] == 4 and masked_fg.shape[2] == 3:
    masked_bg = cv2.cvtColor(masked_bg, cv2.COLOR_BGRA2BGR)

added = cv2.add(masked_fg, masked_bg)

# Ensure 'added' fits within the ROI
if added.shape[:2] != roi.shape[:2]:
    added = cv2.resize(added, (roi.shape[1], roi.shape[0]), interpolation=cv2.INTER_AREA)

img_bg[10:10 + h, 10:10 + w] = added

# 결과 출력
cv2.imshow('mask', mask)
cv2.imshow('mask_inv', mask_inv)
cv2.imshow('masked_fg', masked_fg)
cv2.imshow('masked_bg', masked_bg)
cv2.imshow('added', added)
cv2.imshow('result', img_bg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 큐브 영상 읽어서 HSV로 변환
img = cv2.imread("../data/img/cube.jpg")
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

#--② 색상별 영역 지정
blue1 = np.array([90, 50, 50])
blue2 = np.array([120, 255,255])
green1 = np.array([45, 50,50])
green2 = np.array([75, 255,255])
red1 = np.array([0, 50,50])
red2 = np.array([15, 255,255])
red3 = np.array([165, 50,50])
red4 = np.array([180, 255,255])
yellow1 = np.array([20, 50,50])
yellow2 = np.array([35, 255,255])

# --③ 색상에 따른 마스크 생성
mask_blue = cv2.inRange(hsv, blue1, blue2)
mask_green = cv2.inRange(hsv, green1, green2)
mask_red = cv2.inRange(hsv, red1, red2)
mask_red2 = cv2.inRange(hsv, red3, red4)
mask_yellow = cv2.inRange(hsv, yellow1, yellow2)

#--④ 색상별 마스크로 색상만 추출
res_blue = cv2.bitwise_and(img, img, mask=mask_blue)
res_green = cv2.bitwise_and(img, img, mask=mask_green)
res_red1 = cv2.bitwise_and(img, img, mask=mask_red)
res_red2 = cv2.bitwise_and(img, img, mask=mask_red2)
res_red = cv2.bitwise_or(res_red1, res_red2)
res_yellow = cv2.bitwise_and(img, img, mask=mask_yellow)

#--⑤ 결과 출력
imgs = {'original': img, 'blue':res_blue, 'green':res_green, 
                            'red':res_red, 'yellow':res_yellow}
for i, (k, v) in enumerate(imgs.items()):
    plt.subplot(2,3, i+1)
    plt.title(k)
    plt.imshow(v[:,:,::-1])
    plt.xticks([]); plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
import os

# 파일 경로 설정 (절대 경로 사용)
foreground_path = '../data/img/ccc.png'
background_path = '../data/img/eee.png'

# 이미지 파일이 존재하는지 확인
if not os.path.isfile(foreground_path):
    raise FileNotFoundError(f"Foreground image not found or unable to load: {foreground_path}")

if not os.path.isfile(background_path):
    raise FileNotFoundError(f"Background image not found or unable to load: {background_path}")

# --① 합성에 사용할 영상 읽기, 전경 영상은 4채널 png 파일
img_fg = cv2.imread(foreground_path, cv2.IMREAD_UNCHANGED)
img_bg = cv2.imread(background_path)
 
# 파일을 제대로 읽었는지 확인
if img_fg is None or img_bg is None:
    raise ValueError("Error loading images.")
 

# --② 알파채널을 이용해서 마스크와 역마스크 생성
if img_fg.shape[2] == 4:
    # Alpha channel present
    alpha_channel = img_fg[:, :, 3]
    _, mask = cv2.threshold(alpha_channel, 1, 255, cv2.THRESH_BINARY)
    mask = mask.astype(np.uint8)  # Ensure mask is uint8
    mask_inv = cv2.bitwise_not(mask)
    img_fg = cv2.cvtColor(img_fg, cv2.COLOR_BGRA2BGR)
else:
    # No alpha channel present
    mask = np.ones((img_fg.shape[0], img_fg.shape[1]), dtype=np.uint8) * 255
    mask_inv = np.zeros_like(mask)

# --③ 전경 영상 크기로 배경 영상에서 ROI 잘라내기
h, w = img_fg.shape[:2]

# Check if ROI dimensions are within the background image
if h > img_bg.shape[0] or w > img_bg.shape[1]:
    raise ValueError("Foreground image is larger than the background image.")

# Extract ROI from background
roi = img_bg[10:10 + h, 10:10 + w]

# Ensure ROI has the same number of channels as img_fg
if roi.shape[2] == 3:  # Convert ROI to have 4 channels if needed
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2BGRA)

# --④ 마스크 이용해서 오려내기
if roi.shape[:2] != mask.shape[:2]:
    roi = cv2.resize(roi, (mask.shape[1], mask.shape[0]), interpolation=cv2.INTER_AREA)

masked_fg = cv2.bitwise_and(img_fg, img_fg, mask=mask)
masked_bg = cv2.bitwise_and(roi, roi, mask=mask_inv)

# --⑥ 이미지 합성
if masked_fg.shape[:2] != masked_bg.shape[:2]:
    masked_bg = cv2.resize(masked_bg, (masked_fg.shape[1], masked_fg.shape[0]), interpolation=cv2.INTER_AREA)

# Ensure same number of channels
if masked_bg.shape[2] == 3 and masked_fg.shape[2] == 3:
    masked_bg = cv2.cvtColor(masked_bg, cv2.COLOR_BGRA2BGR)
elif masked_bg.shape[2] == 4 and masked_fg.shape[2] == 3:
    masked_bg = cv2.cvtColor(masked_bg, cv2.COLOR_BGRA2BGR)

added = cv2.add(masked_fg, masked_bg)

# Ensure 'added' fits within the ROI
if added.shape[:2] != roi.shape[:2]:
    added = cv2.resize(added, (roi.shape[1], roi.shape[0]), interpolation=cv2.INTER_AREA)

img_bg[10:10 + h, 10:10 + w] = added

# 결과 출력
# cv2.imshow('mask', mask)
cv2.imshow('mask_inv', mask_inv)
cv2.imshow('masked_fg', masked_fg)
# cv2.imshow('masked_bg', masked_bg)
# cv2.imshow('added', added)
cv2.imshow('result', img_bg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import os

# 파일 경로 설정 (절대 경로 사용)
foreground_path = '../data/img/ddd.png'
background_path = '../data/img/eee.png'

# 이미지 파일이 존재하는지 확인
if not os.path.isfile(foreground_path):
    raise FileNotFoundError(f"Foreground image not found or unable to load: {foreground_path}")

if not os.path.isfile(background_path):
    raise FileNotFoundError(f"Background image not found or unable to load: {background_path}")

# --① 합성에 사용할 영상 읽기
img_fg = cv2.imread(foreground_path, cv2.IMREAD_UNCHANGED)
img_bg = cv2.imread(background_path)

# 파일을 제대로 읽었는지 확인
if img_fg is None or img_bg is None:
    raise ValueError("Error loading images.")

# --② 알파채널을 이용해서 마스크와 역마스크 생성
if img_fg.shape[2] == 4:
    print("Alpha channel present")
    alpha_channel = img_fg[:, :, 2]
    _, mask = cv2.threshold(alpha_channel, 10, 255, cv2.THRESH_BINARY)
    mask = mask.astype(np.uint8)  # Ensure mask is uint8
    mask_inv = cv2.bitwise_not(mask)
    img_fg = cv2.cvtColor(img_fg, cv2.COLOR_BGRA2BGR)
else:
    print("No alpha channel present, create a full opaque mask")    
    mask = np.ones((img_fg.shape[0], img_fg.shape[1]), dtype=np.uint8) * 255
    mask_inv = np.zeros_like(mask)

# Resize mask to a smaller size if needed
desired_size = (200, 200)  # Example size, adjust as needed
mask_resized = cv2.resize(mask, desired_size, interpolation=cv2.INTER_AREA)
mask_inv_resized = cv2.resize(mask_inv, desired_size, interpolation=cv2.INTER_AREA)

# Resize foreground to match the resized mask
img_fg_resized = cv2.resize(img_fg, desired_size, interpolation=cv2.INTER_AREA)

# Ensure background image is large enough to accommodate the resized foreground
if img_fg_resized.shape[0] > img_bg.shape[0] or img_fg_resized.shape[1] > img_bg.shape[1]:
    raise ValueError("Foreground image is larger than the background image.")

# Extract ROI from background
roi = img_bg[10:10 + img_fg_resized.shape[0], 10:10 + img_fg_resized.shape[1]]

# Resize ROI to match the resized mask
roi_resized = cv2.resize(roi, desired_size, interpolation=cv2.INTER_AREA)

# --④ 마스크 이용해서 오려내기
masked_fg = cv2.bitwise_and(img_fg_resized, img_fg_resized, mask=mask_resized)
masked_bg = cv2.bitwise_and(roi_resized, roi_resized, mask=mask_inv_resized)

# --⑥ 이미지 합성
# Ensure the dimensions of masked_fg and masked_bg are the same
if masked_fg.shape != masked_bg.shape:
    raise ValueError("Dimensions of masked_fg and masked_bg do not match.")

added = cv2.add(masked_fg, masked_bg)
img_bg[10:10 + img_fg_resized.shape[0], 10:10 + img_fg_resized.shape[1]] = added

# 결과 출력
cv2.imshow('mask_resized', mask_resized)
cv2.imshow('mask_inv_resized', mask_inv_resized)
# cv2.imshow('masked_fg', masked_fg)
# cv2.imshow('masked_bg', masked_bg)
cv2.imshow('added', added)
# cv2.imshow('result', img_bg)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Alpha channel present

# %% [markdown]
# ###  잘 되는거

# %%
import cv2
import numpy as np
import os

# File paths
foreground_path = '../../data/img/zzz.jpg'
background_path = '../../data/img/eee.png'

# Check if images exist
if not os.path.isfile(foreground_path):
    raise FileNotFoundError(f"Foreground image not found: {foreground_path}")
if not os.path.isfile(background_path):
    raise FileNotFoundError(f"Background image not found: {background_path}")

# Load images
img_fg = cv2.imread(foreground_path, cv2.IMREAD_UNCHANGED)
img_bg = cv2.imread(background_path)

# Check if images loaded properly
if img_fg is None or img_bg is None:
    raise ValueError("Error loading images.")

# Convert foreground to grayscale to create a mask
gray_fg = cv2.cvtColor(img_fg, cv2.COLOR_BGR2GRAY)

# Create a mask where white areas are set to 0 (background) and other areas to 255 (foreground)
_, mask = cv2.threshold(gray_fg, 240, 255, cv2.THRESH_BINARY_INV)

# Invert the mask
mask_inv = cv2.bitwise_not(mask)

# Resize the foreground image and mask if necessary
desired_size = (200, 200)
img_fg_resized = cv2.resize(img_fg, desired_size, interpolation=cv2.INTER_AREA)
mask_resized = cv2.resize(mask, desired_size, interpolation=cv2.INTER_AREA)
mask_inv_resized = cv2.resize(mask_inv, desired_size, interpolation=cv2.INTER_AREA)

# Ensure the foreground fits within the background
if img_fg_resized.shape[0] > img_bg.shape[0] or img_fg_resized.shape[1] > img_bg.shape[1]:
    raise ValueError("Foreground image is larger than the background image.") 

# Calculate the center position
bg_height, bg_width = img_bg.shape[:2]
fg_height, fg_width = img_fg_resized.shape[:2]
center_y = (bg_height - fg_height) // 2
center_x = (bg_width - fg_width) // 2

# Extract region of interest from background
# roi = img_bg[10:10 + img_fg_resized.shape[0], 10:10 + img_fg_resized.shape[1]]
roi = img_bg[center_y:center_y + img_fg_resized.shape[0], center_x:center_x + img_fg_resized.shape[1]]

# Apply masks to blend images
masked_fg = cv2.bitwise_and(img_fg_resized, img_fg_resized, mask=mask_resized)
masked_bg = cv2.bitwise_and(roi, roi, mask=mask_inv_resized)

# Combine the masked foreground and background
added = cv2.add(masked_fg, masked_bg)
# img_bg[10:10 + img_fg_resized.shape[0] , 10:10 + img_fg_resized.shape[1]] = added
img_bg[center_y:center_y + img_fg_resized.shape[0], center_x:center_x + img_fg_resized.shape[1]] = added

# Display the result
cv2.imshow('Result', img_bg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 크로마키 배경 영상과 합성할 배경 영상 읽기
img1 = cv2.imread('../data/img/2222.jpg')
img2 = cv2.imread('../data/img/ddd.png')

#--② ROI 선택을 위한 좌표 계산
height1, width1 = img1.shape[:2]
height2, width2 = img2.shape[:2]
x = (width2 - width1)//2
y = height2 - height1
w = x + width1
h = y + height1

#--③ 크로마키 배경 영상에서 크로마키 영역을 10픽셀 정도로 지정
chromakey = img1[:10, :10, :]
offset = 20

#--④ 크로마키 영역과 영상 전체를 HSV로 변경
hsv_chroma = cv2.cvtColor(chromakey, cv2.COLOR_BGR2HSV)
hsv_img = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)

#--⑤ 크로마키 영역의 H값에서 offset 만큼 여유를 두어서 범위 지정
# offset 값은 여러차례 시도 후 결정
#chroma_h = hsv_chroma[0]
chroma_h = hsv_chroma[:,:,0]
lower = np.array([chroma_h.min()-offset, 100, 100])
upper = np.array([chroma_h.max()+offset, 255, 255])

#--⑥ 마스크 생성 및 마스킹 후 합성
mask = cv2.inRange(hsv_img, lower, upper)
mask_inv = cv2.bitwise_not(mask)
roi = img2[y:h, x:w]
fg = cv2.bitwise_and(img1, img1, mask=mask_inv)
bg = cv2.bitwise_and(roi, roi, mask=mask)
img2[y:h, x:w] = fg + bg

#--⑦ 결과 출력
# cv2.imshow('chromakey', img1)
cv2.imshow('added', img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt
 
#--① 합성 대상 영상 읽기
img1 = cv2.imread("../data/img/drawing.jpg")
img2= cv2.imread("../data/img/cropped.jpg")

#--② 마스크 생성, 합성할 이미지 전체 영역을 255로 셋팅
mask = np.full_like(img1, 255)
 
#--③ 합성 대상 좌표 계산(img2의 중앙)
height, width = img2.shape[:2]
center = ((width//2)-20 , (height//2)-20)
 
#--④ seamlessClone 으로 합성 
normal = cv2.seamlessClone(img1, img2, mask, center, cv2.NORMAL_CLONE)
mixed = cv2.seamlessClone(img1, img2, mask, center, cv2.MIXED_CLONE)

#--⑤ 결과 출력
# cv2.imshow('normal', normal)
cv2.imshow('mixed', mixed)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 큐브 영상 읽어서 HSV로 변환
img = cv2.imread("../data/img/cube.jpg")
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

#--② 색상별 영역 지정
blue1 = np.array([90, 50, 50])
blue2 = np.array([120, 255,255])
green1 = np.array([45, 50,50])
green2 = np.array([75, 255,255])
red1 = np.array([0, 50,50])
red2 = np.array([15, 255,255])
red3 = np.array([165, 50,50])
red4 = np.array([180, 255,255])
yellow1 = np.array([20, 50,50])
yellow2 = np.array([35, 255,255])

# --③ 색상에 따른 마스크 생성
mask_blue = cv2.inRange(hsv, blue1, blue2)
mask_green = cv2.inRange(hsv, green1, green2)
mask_red = cv2.inRange(hsv, red1, red2)
mask_red2 = cv2.inRange(hsv, red3, red4)
mask_yellow = cv2.inRange(hsv, yellow1, yellow2)

#--④ 색상별 마스크로 색상만 추출
res_blue = cv2.bitwise_and(img, img, mask=mask_blue)
res_green = cv2.bitwise_and(img, img, mask=mask_green)
res_red1 = cv2.bitwise_and(img, img, mask=mask_red)
res_red2 = cv2.bitwise_and(img, img, mask=mask_red2)
res_red = cv2.bitwise_or(res_red1, res_red2)
res_yellow = cv2.bitwise_and(img, img, mask=mask_yellow)

#--⑤ 결과 출력
imgs = {'original': img, 'blue':res_blue, 'green':res_green, 
                            'red':res_red, 'yellow':res_yellow}
for i, (k, v) in enumerate(imgs.items()):
    plt.subplot(2,3, i+1)
    plt.title(k)
    plt.imshow(v[:,:,::-1])
    plt.xticks([]); plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 큐브 영상 읽어서 HSV로 변환
img = cv2.imread("../../data/img/2222.jpg")
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

#--② 색상별 영역 지정
blue1 = np.array([90, 50, 50])
blue2 = np.array([120, 255,255])
green1 = np.array([45, 50,50])
green2 = np.array([75, 255,255])
red1 = np.array([0, 50,50])
red2 = np.array([15, 255,255])
red3 = np.array([165, 50,50])
red4 = np.array([180, 255,255])
yellow1 = np.array([20, 50,50])
yellow2 = np.array([35, 255,255])

# --③ 색상에 따른 마스크 생성
mask_blue = cv2.inRange(hsv, blue1, blue2)
mask_green = cv2.inRange(hsv, green1, green2)
mask_red = cv2.inRange(hsv, red1, red2)
mask_red2 = cv2.inRange(hsv, red3, red4)
mask_yellow = cv2.inRange(hsv, yellow1, yellow2)

#--④ 색상별 마스크로 색상만 추출
res_blue = cv2.bitwise_and(img, img, mask=mask_blue)
res_green = cv2.bitwise_and(img, img, mask=mask_green)
res_red1 = cv2.bitwise_and(img, img, mask=mask_red)
res_red2 = cv2.bitwise_and(img, img, mask=mask_red2)
res_red = cv2.bitwise_or(res_red1, res_red2)
res_yellow = cv2.bitwise_and(img, img, mask=mask_yellow)

#--⑤ 결과 출력
imgs = {'original': img, 'blue':res_blue, 'green':res_green, 
                            'red':res_red, 'yellow':res_yellow}
for i, (k, v) in enumerate(imgs.items()):
    plt.subplot(2,3, i+1)
    plt.title(k)
    plt.imshow(v[:,:,::-1])
    plt.xticks([]); plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 이미지 그레이 스케일로 읽기 및 출력
img = cv2.imread('../data/img/bbb.png', cv2.IMREAD_GRAYSCALE) 

#--② 히스토그램 계산 및 그리기
hist = cv2.calcHist([img], [0], None, [256], [0,255])
plt.plot(hist)

print("hist.shape:", hist.shape)  #--③ 히스토그램의 shape (256,1)
print("hist.sum():", hist.sum(), "img.shape:",img.shape) #--④ 히스토그램 총 합계와 이미지의 크기
plt.show()

# Optional: if you want to use cv2.imshow
cv2.imshow('img', img)
cv2.waitKey(0)  # Wait for a key press to close the image window
cv2.destroyAllWindows()
# Out:
# hist.shape: (256, 1)
# hist.sum(): 435714.0 img.shape: (719, 606)

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 이미지 읽기 및 출력
img = cv2.imread('../data/img/mountain.jpg') 
#--② 히스토그램 계산 및 그리기
channels = cv2.split(img)
colors = ('b', 'g', 'r')
for (ch, color) in zip (channels, colors):
    hist = cv2.calcHist([ch], [0], None, [256], [0, 255])
    plt.plot(hist, color = color)
plt.show()

# Optional: if you want to use cv2.imshow
cv2.imshow('img', img)
cv2.waitKey(0)  # Wait for a key press to close the image window
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 이미지 읽기 및 출력
img = cv2.imread('../data/img/monkey.jpg')
 

#--② 히스토그램 계산 및 그리기
channels = cv2.split(img)
colors = ('b', 'g', 'r')
for (ch, color) in zip (channels, colors):
    hist = cv2.calcHist([ch], [0], None, [256], [0, 255])
    plt.plot(hist, color = color)
plt.show()


# Optional: if you want to use cv2.imshow
cv2.imshow('img', img)
cv2.waitKey(0)  # Wait for a key press to close the image window
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 이미지 읽기 및 출력
img = cv2.imread('../data/img/monkey.jpg')

# Use matplotlib to display the image
plt.figure(figsize=(5, 3))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color representation
plt.title('Image')
plt.axis('off')  # Hide axes
plt.show()

#--② 히스토그램 계산 및 그리기
channels = cv2.split(img)
colors = ('b', 'g', 'r')
plt.figure()
for (ch, color) in zip(channels, colors):
    hist = cv2.calcHist([ch], [0], None, [256], [0, 255])
    plt.plot(hist, color=color)
plt.title('Histogram')
plt.show()

# Optional: if you want to use cv2.imshow
# cv2.imshow('img', img)
# cv2.waitKey(0)  # Wait for a key press to close the image window
# cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 이미지 읽기 및 출력
img = cv2.imread('../data/img/mountain.jpg') 

#--② 히스토그램 계산 및 그리기
channels = cv2.split(img)
colors = ('b', 'g', 'r')
for (ch, color) in zip (channels, colors):
    hist = cv2.calcHist([ch], [0], None, [256], [0, 255])
    plt.plot(hist, color = color)
plt.show()

cv2.imshow('img', img)
cv2.waitKey(0)  # Wait for a key press to close the image window
cv2.destroyAllWindows()

# %% [markdown]
# ## 이미지 노말라이즈

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 그레이 스케일로 영상 읽기
img = cv2.imread('../data/img/cpu.png', cv2.IMREAD_GRAYSCALE)

#--② 직접 연산한 정규화
img_f = img.astype(np.float32)
img_norm = ((img_f - img_f.min()) * (255) / (img_f.max() - img_f.min()))
img_norm = img_norm.astype(np.uint8)

#--③ OpenCV API를 이용한 정규화
img_norm2 = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX)

#--④ 히스토그램 계산
hist = cv2.calcHist([img], [0], None, [256], [0, 255])
hist_norm = cv2.calcHist([img_norm], [0], None, [256], [0, 255])
hist_norm2 = cv2.calcHist([img_norm2], [0], None, [256], [0, 255])



hists = {'Before' : hist, 'Manual':hist_norm, 'cv2.normalize()':hist_norm2}
for i, (k, v) in enumerate(hists.items()):
    plt.subplot(1,3,i+1)
    plt.title(k)
    plt.plot(v)
plt.show()


cv2.imshow('Before', img)
cv2.imshow('Manual', img_norm)
cv2.imshow('cv2.normalize()', img_norm2)
cv2.waitKey(0)  # Wait for a key press to close the image window
cv2.destroyAllWindows()

# %%
import numpy as np, cv2

img = cv2.imread('../data/img/cpu.png') #이미지 읽기, BGR 스케일

#--① 컬러 스케일을 BGR에서 YUV로 변경
img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV) 

#--② YUV 컬러 스케일의 첫번째 채널에 대해서 이퀄라이즈 적용
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0]) 

#--③ 컬러 스케일을 YUV에서 BGR로 변경
img2 = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR) 

cv2.imshow('Before', img)
cv2.imshow('After', img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import numpy as np, cv2

img = cv2.imread('../data/img/dragon.jpg') #이미지 읽기, BGR 스케일

#--① 컬러 스케일을 BGR에서 YUV로 변경
img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV) 

#--② YUV 컬러 스케일의 첫번째 채널에 대해서 이퀄라이즈 적용
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0]) 

#--③ 컬러 스케일을 YUV에서 BGR로 변경
img2 = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR) 

cv2.imshow('Before', img)
cv2.imshow('After', img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--①이미지 읽어서 YUV 컬러스페이스로 변경
img = cv2.imread('../data/img/dragon.jpg')
img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

#--② 밝기 채널에 대해서 이퀄라이즈 적용
img_eq = img_yuv.copy()
img_eq[:,:,0] = cv2.equalizeHist(img_eq[:,:,0])
img_eq = cv2.cvtColor(img_eq, cv2.COLOR_YUV2BGR)

#--③ 밝기 채널에 대해서 CLAHE 적용
img_clahe = img_yuv.copy()
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8)) #CLAHE 생성
img_clahe[:,:,0] = clahe.apply(img_clahe[:,:,0])           #CLAHE 적용
img_clahe = cv2.cvtColor(img_clahe, cv2.COLOR_YUV2BGR)

#--④ 결과 출력
cv2.imshow('Before', img)
cv2.imshow('CLAHE', img_clahe)
cv2.imshow('equalizeHist', img_eq)
cv2.waitKey()
cv2.destroyAllWindows()
