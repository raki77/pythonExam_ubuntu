# %%
# !pip install gradio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gradio
#   Downloading gradio-4.44.0-py3-none-any.whl.metadata (15 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Using cached aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (4.5.0)
# Collecting fastapi<1.0 (from gradio)
#   Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Using cached ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.3.0 (from gradio)
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (0.27.2)
# Collecting huggingface-hub>=0.19.3 (from gradio)
#   Downloading huggingface_hub-0.25.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (6.4.2)
# Collecting jinja2<4.0 (from gradio)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting markupsafe~=2.0 (from gradio)
#   Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: matplotlib~=3.0 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (3.7.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (1.24.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.7-cp38-none-win_amd64.whl.metadata (51 kB)
# Requirement already satisfied: packaging in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (24.1)
# Collecting pandas<3.0,>=1.0 (from gradio)
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (2.9.2)
# Collecting pydub (from gradio)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.10-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.6.7-py3-none-win_amd64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Using cached tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in c:\anaconda3\envs\cv2\lib\site-packages (from gradio) (2.2.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting fsspec (from gradio-client==1.3.0->gradio)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.3.0->gradio)
#   Downloading websockets-12.0-cp38-cp38-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: idna>=2.8 in c:\anaconda3\envs\cv2\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.8)
# Requirement already satisfied: sniffio>=1.1 in c:\anaconda3\envs\cv2\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\anaconda3\envs\cv2\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi<1.0->gradio)
#   Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: certifi in c:\anaconda3\envs\cv2\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\anaconda3\envs\cv2\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\anaconda3\envs\cv2\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Collecting filelock (from huggingface-hub>=0.19.3->gradio)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: requests in c:\anaconda3\envs\cv2\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\anaconda3\envs\cv2\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\anaconda3\envs\cv2\lib\site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda3\envs\cv2\lib\site-packages (from matplotlib~=3.0->gradio) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\envs\cv2\lib\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\envs\cv2\lib\site-packages (from matplotlib~=3.0->gradio) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda3\envs\cv2\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda3\envs\cv2\lib\site-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda3\envs\cv2\lib\site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3.0,>=1.0->gradio)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas<3.0,>=1.0->gradio)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\anaconda3\envs\cv2\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\anaconda3\envs\cv2\lib\site-packages (from pydantic>=2.0->gradio) (2.23.4)
# Collecting click>=8.0.0 (from typer<1.0,>=0.12->gradio)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio)
#   Using cached rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in c:\anaconda3\envs\cv2\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\envs\cv2\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda3\envs\cv2\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda3\envs\cv2\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading gradio-4.44.0-py3-none-any.whl (18.1 MB)
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    --------------------------- ------------ 12.3/18.1 MB 55.1 MB/s eta 0:00:01
#    -------------------------------------- - 17.6/18.1 MB 41.0 MB/s eta 0:00:01
#    ---------------------------------------- 18.1/18.1 MB 35.6 MB/s eta 0:00:00
# Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
# Using cached tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.0-py3-none-any.whl (94 kB)
# Downloading huggingface_hub-0.25.1-py3-none-any.whl (436 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
# Downloading orjson-3.10.7-cp38-none-win_amd64.whl (137 kB)
# Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
# Downloading python_multipart-0.0.10-py3-none-any.whl (22 kB)
# Downloading ruff-0.6.7-py3-none-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------- ----------------------- 3.9/9.3 MB 19.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 32.1 MB/s eta 0:00:00
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
# Using cached ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached rich-13.8.1-py3-none-any.whl (241 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.38.6-py3-none-any.whl (71 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading websockets-12.0-cp38-cp38-win_amd64.whl (124 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, pydub, websockets, tzdata, tomlkit, shellingham, semantic-version, ruff, python-multipart, orjson, mdurl, markupsafe, fsspec, filelock, ffmpy, click, aiofiles, uvicorn, starlette, pandas, markdown-it-py, jinja2, huggingface-hub, rich, gradio-client, fastapi, typer, gradio
# Successfully installed aiofiles-23.2.1 click-8.1.7 fastapi-0.115.0 ffmpy-0.4.0 filelock-3.16.1 fsspec-2024.9.0 gradio-4.44.0 gradio-client-1.3.0 huggingface-hub-0.25.1 jinja2-3.1.4 markdown-it-py-3.0.0 markupsafe-2.1.5 mdurl-0.1.2 orjson-3.10.7 pandas-2.0.3 pydub-0.25.1 python-multipart-0.0.10 pytz-2024.2 rich-13.8.1 ruff-0.6.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.38.6 tomlkit-0.12.0 typer-0.12.5 tzdata-2024.2 uvicorn-0.30.6 websockets-12.0
#   WARNING: The script uvicorn.exe is installed in 'C:\Users\shjung\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'C:\Users\shjung\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script huggingface-cli.exe is installed in 'C:\Users\shjung\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fastapi.exe is installed in 'C:\Users\shjung\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'C:\Users\shjung\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts gradio.exe and upload_theme.exe are installed in 'C:\Users\shjung\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import random
import gradio as gr


def random_response(message, history):
    products = {
        "적금 상품" : "111111111111",
        "대출 상품" : "222222222222",
        "신용 카드" : "33333333333",
        "예금 상품" : "444444444444",
        "주택청약 통장" : "5555555555555"
    }
    greetings = [
        "고객님 안녕하세요.",
        "고객님 어떤 은행 상품을 안내해드릴까요?"
    ]

    for idx in products.keys():        
        if idx == message:
            response = products[message]      
            break      
        else:
            response = random.choice(greetings)

    yield response


demo = gr.ChatInterface(random_response)

if __name__ == "__main__":
    demo.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7864
# Running on public URL: https://9e7808cf493b513523.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9e7808cf493b513523.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 적금 상품 123123
# 대출 상품 123123
# 신용 카드 123123
# 예금 상품 123123
# 주택청약 통장 123123
# 적금 상품 대출 상품
# 대출 상품 대출 상품
# Traceback (most recent call last):
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\blocks.py", line 1935, in process_api
#     result = await self.call_function(
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\blocks.py", line 1532, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 671, in async_iteration
#     return await iterator.__anext__()
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 776, in asyncgen_wrapper
#     response = await iterator.__anext__()
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\chat_interface.py", line 653, in _stream_fn
#     first_response = await async_iteration(generator)
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 671, in async_iteration
#     return await iterator.__anext__()
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 664, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "c:\anaconda3\envs\cv2\lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "c:\anaconda3\envs\cv2\lib\site-packages\anyio\_backends\_asyncio.py", line 2357, in run_sync_in_worker_thread
#     return await future
#   File "c:\anaconda3\envs\cv2\lib\site-packages\anyio\_backends\_asyncio.py", line 864, in run
#     result = context.run(func, *args)
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 647, in run_sync_iterator_async
#     return next(iterator)
#   File "C:\Users\shjung\AppData\Local\Temp\ipykernel_12700\2487463227.py", line 19, in random_response
#     product = random.choice(products)
#   File "c:\anaconda3\envs\cv2\lib\random.py", line 291, in choice
#     return seq[i]
# KeyError: 4
# Traceback (most recent call last):
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\blocks.py", line 1935, in process_api
#     result = await self.call_function(
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\blocks.py", line 1532, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 671, in async_iteration
#     return await iterator.__anext__()
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 776, in asyncgen_wrapper
#     response = await iterator.__anext__()
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\chat_interface.py", line 653, in _stream_fn
#     first_response = await async_iteration(generator)
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 671, in async_iteration
#     return await iterator.__anext__()
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 664, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "c:\anaconda3\envs\cv2\lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "c:\anaconda3\envs\cv2\lib\site-packages\anyio\_backends\_asyncio.py", line 2357, in run_sync_in_worker_thread
#     return await future
#   File "c:\anaconda3\envs\cv2\lib\site-packages\anyio\_backends\_asyncio.py", line 864, in run
#     result = context.run(func, *args)
#   File "C:\Users\shjung\AppData\Roaming\Python\Python38\site-packages\gradio\utils.py", line 647, in run_sync_iterator_async
#     return next(iterator)
#   File "C:\Users\shjung\AppData\Local\Temp\ipykernel_12700\2487463227.py", line 19, in random_response
#     product = random.choice(products)
#   File "c:\anaconda3\envs\cv2\lib\random.py", line 291, in choice
#     return seq[i]
# KeyError: 0
